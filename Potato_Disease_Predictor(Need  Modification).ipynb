# %% [markdown]
# <a href="https://colab.research.google.com/github/NazHub1993/Deep-Learning/blob/main/Potato_Disease_Predictor(Need%20%20Modification).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import models,layers
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = "/content/drive/MyDrive/Potato_Disease_Predictor"

# %%
IMAGE_SIZE=256
BATCH_SIZE=32
CHANNELS=3
EPOCHS=50

# %%
dataset=tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    shuffle=True,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names=dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
len(dataset)
# Out:
# 68

# %%
plt.figure(figsize=(10,12))
for image_batch,label_batch in dataset.take(1):
  for i in range(12):
    ax=plt.subplot(3,4,i+1)
    plt.imshow(image_batch[i].numpy().astype('uint8'))
    plt.title(class_names[label_batch[i].numpy()])

# %% [markdown]
# #Partitioning the dataset for train and test

# %%
def get_dataset_partitions(ds,train_split=0.8,val_split=0.1,test_split=0.1,shuffle=True,shuffle_size=1000):
  ds_size=len(dataset)
  if shuffle:
    ds=ds.shuffle(shuffle_size,seed=12)

  train_size=int(train_split*ds_size)
  val_size=int(val_split*ds_size)

  train_ds=dataset.take(train_size)
  val_ds=dataset.skip(train_size).take(val_size)
  test_ds=dataset.skip(train_size).skip(val_size)

  return train_ds,val_ds,test_ds

# %%
train_ds,val_ds,test_ds=get_dataset_partitions(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %%
train_ds=train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds=val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds=test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %% [markdown]
# #Adding the preprocessing layers

# %%
resize_rescale=tf.keras.Sequential(
    [
        layers.Resizing(IMAGE_SIZE,IMAGE_SIZE),
        layers.Rescaling(1.0/255)
    ]
)

# %%
data_augmentation=tf.keras.Sequential(
    [
        layers.RandomFlip("horizontal_and_vertical"),
        layers.RandomRotation(0.2)
    ]
)

# %% [markdown]
# #Building the CNN model

# %%
input_shape=(BATCH_SIZE,IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes=3

from tensorflow.keras import models
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout,BatchNormalization

# %%
model=models.Sequential()

model.add(resize_rescale)
model.add(data_augmentation)

model.add(Conv2D(32,(3,3),activation='relu',padding='valid',input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,(3,3),activation='relu',padding='valid'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,(3,3),activation='relu',padding='valid'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,(3,3),activation='relu',padding='valid'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,(3,3),activation='relu',padding='valid'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(n_classes,activation='softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.build(input_shape=input_shape)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (32, 256, 256, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (32, 254, 254, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (32, 254, 254, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (32, 127, 127, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (32, 125, 125, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (32, 125, 125, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (32, 62, 62, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (32, 60, 60, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (32, 60, 60, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (32, 30, 30, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (32, 28, 28, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (32, 28, 28, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (32, 14, 14, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (32, 12, 12, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (32, 12, 12, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (32, 6, 6, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (32, 2304)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 64)               │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (32, 64)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (32, 3)                │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 279,043 (1.06 MB)
#  Trainable params: 278,467 (1.06 MB)
#  Non-trainable params: 576 (2.25 KB)

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
history=model.fit(train_ds,
          epochs=EPOCHS,
          batch_size=BATCH_SIZE,
          verbose=1,
          validation_data=val_ds)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 282s 819ms/step - accuracy: 0.8819 - loss: 0.4199 - val_accuracy: 0.4583 - val_loss: 5.0256
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.9253 - loss: 0.1964 - val_accuracy: 0.4583 - val_loss: 10.8690
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.9572 - loss: 0.1405 - val_accuracy: 0.4583 - val_loss: 13.7445
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.9543 - loss: 0.1291 - val_accuracy: 0.4583 - val_loss: 14.0367
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9427 - loss: 0.1516 - val_accuracy: 0.4583 - val_loss: 18.6487
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9537 - loss: 0.1300 - val_accuracy: 0.4583 - val_loss: 14.9245
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9606 - loss: 0.1145 - val_accuracy: 0.4583 - val_loss: 20.8804
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9670 - loss: 0.0974 - val_accuracy: 0.4583 - val_loss: 16.5093
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.9578 - loss: 0.1212 - val_accuracy: 0.8594 - val_loss: 1.0765
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9745 - loss: 0.0750 - val_accuracy: 0.8542 - val_loss: 0.9714
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9676 - loss: 0.0959 - val_accuracy: 0.8646 - val_loss: 0.7476
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9792 - loss: 0.0591 - val_accuracy: 0.8490 - val_loss: 0.5929
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9745 - loss: 0.0686 - val_accuracy: 0.8698 - val_loss: 0.5629
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9699 - loss: 0.0834 - val_accuracy: 0.7656 - val_loss: 2.0209
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.9728 - loss: 0.0748 - val_accuracy: 0.9427 - val_loss: 0.1819
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9774 - loss: 0.0602 - val_accuracy: 0.9375 - val_loss: 0.2782
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9716 - loss: 0.0798 - val_accuracy: 0.7135 - val_loss: 4.2032
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9838 - loss: 0.0635 - val_accuracy: 0.8490 - val_loss: 0.6423
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9867 - loss: 0.0442 - val_accuracy: 0.8281 - val_loss: 1.3270
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9844 - loss: 0.0499 - val_accuracy: 0.7500 - val_loss: 2.9114
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9821 - loss: 0.0699 - val_accuracy: 0.7396 - val_loss: 1.7895
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9780 - loss: 0.0636 - val_accuracy: 0.9271 - val_loss: 0.4486
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9850 - loss: 0.0533 - val_accuracy: 0.6146 - val_loss: 5.0290
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9878 - loss: 0.0328 - val_accuracy: 0.6979 - val_loss: 2.5012
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9884 - loss: 0.0373 - val_accuracy: 0.6302 - val_loss: 4.6492
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9896 - loss: 0.0420 - val_accuracy: 0.6562 - val_loss: 2.3857
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9832 - loss: 0.0521 - val_accuracy: 0.9062 - val_loss: 0.3470
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9884 - loss: 0.0333 - val_accuracy: 0.9062 - val_loss: 0.5434
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9884 - loss: 0.0410 - val_accuracy: 0.9427 - val_loss: 0.3132
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9884 - loss: 0.0352 - val_accuracy: 0.9740 - val_loss: 0.0587
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9942 - loss: 0.0182 - val_accuracy: 0.9792 - val_loss: 0.0376
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9907 - loss: 0.0302 - val_accuracy: 0.6042 - val_loss: 5.0361
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9873 - loss: 0.0327 - val_accuracy: 0.5156 - val_loss: 11.1101
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9826 - loss: 0.0574 - val_accuracy: 0.7552 - val_loss: 1.1189
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9896 - loss: 0.0404 - val_accuracy: 0.7188 - val_loss: 2.6741
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9809 - loss: 0.0657 - val_accuracy: 0.9219 - val_loss: 0.3012
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9832 - loss: 0.0391 - val_accuracy: 0.8073 - val_loss: 0.9165
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9873 - loss: 0.0438 - val_accuracy: 0.7396 - val_loss: 1.8139
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9850 - loss: 0.0457 - val_accuracy: 0.9844 - val_loss: 0.0670
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9936 - loss: 0.0173 - val_accuracy: 0.9479 - val_loss: 0.1901
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9954 - loss: 0.0150 - val_accuracy: 0.9792 - val_loss: 0.0789
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.9884 - loss: 0.0325 - val_accuracy: 0.9427 - val_loss: 0.2183
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9884 - loss: 0.0297 - val_accuracy: 0.8177 - val_loss: 1.2494
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9936 - loss: 0.0231 - val_accuracy: 0.9688 - val_loss: 0.1223
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9959 - loss: 0.0139 - val_accuracy: 0.9740 - val_loss: 0.0967
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9925 - loss: 0.0246 - val_accuracy: 0.9323 - val_loss: 0.2476
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9931 - loss: 0.0187 - val_accuracy: 0.9062 - val_loss: 0.4265
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.9925 - loss: 0.0207 - val_accuracy: 0.9271 - val_loss: 0.2879
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.9838 - loss: 0.0442 - val_accuracy: 0.9635 - val_loss: 0.1217
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9919 - loss: 0.0239 - val_accuracy: 0.9062 - val_loss: 0.6479

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 50, 'steps': 54}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
it=50

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,2)
plt.plot(range(EPOCHS),acc,label='Training Accuracy')
plt.plot(range(EPOCHS),val_acc,label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.figure(figsize=(10,10))
plt.subplot(1,2,2)
plt.plot(range(EPOCHS),loss,label='Training Loss')
plt.plot(range(EPOCHS),val_loss,label='Validation Loss')
plt.legend(loc='lower right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %% [markdown]
# #Let's do the prediction!!!

# %%
import numpy as np

# %%
for image_batch,label_batch in test_ds.take(1):
  first_image=image_batch[0].numpy().astype('uint8')
  first_label=label_batch[0].numpy()

  print('First Image to predict:')
  plt.imshow(first_image)
  print("Actual label:",class_names[first_label])

  batch_prediction=model.predict(image_batch)
  print("Predicted label: ",class_names[np.argmax(batch_prediction[0])])
# Out:
# First Image to predict:
# Actual label: Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# Predicted label:  Potato___Late_blight

# %%
def prediction(model, single_image_array):
  img_array=tf.keras.preprocessing.image.img_to_array(single_image_array)
  img_array=tf.expand_dims(img_array,0)

  predictions=model.predict(img_array)
  predicted_class=class_names[np.argmax(predictions[0])]

  confidence=round(100*(np.max(predictions)),2)
  return predicted_class,confidence

# %%
plt.figure(figsize=(20,20))
for image_batch,label_batch in test_ds.take(1):
  for i in range(9):
    ax=plt.subplot(3,3,i+1)
    current_image = image_batch[i].numpy().astype('uint8')
    plt.imshow(current_image)
    predicted_class,confidence=prediction(model, current_image)
    actual_class=class_names[np.argmax(label_batch[i].numpy())]
    plt.title(f"Actual : {actual_class},\n Predicted: {predicted_class},\n Confidence: {confidence}")
    print("Actual Class: ",actual_class)
    print("Predicted Class: ",predicted_class)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Early_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Early_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Early_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Late_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Early_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Early_blight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Actual Class:  Potato___Early_blight
# Predicted Class:  Potato___Early_blight

# %%
model_path = "/content/drive/MyDrive/Potato_Disease_Predictor/plant_model_2.keras"

# Save it
model.save(model_path)
print("Model saved to Google Drive!")
# Out:
# Model saved to Google Drive!
